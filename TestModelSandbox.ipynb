# %%
from FlexibleWM import *

dictionnary = {} # Add here any parameter you want to change from default. Defaults values are at the beginning of FlexibleWM.py
MyModel = FlexibleWM(dictionnary)
MyModel.run_a_trial() 
gcPython.collect()
# Out:
# Initializing the weights of the network that will be used for all trials
#
# ---------- Initialisation of trial 0 ----------
# Load for this trial is 7
# Running...
# Plot of a raster into the folder ..
# Tuning curve is saved in the folder, next time you can include 'compute_tuning_curve':False to reuse it
#
# ---------- ML decoding at the end of trial 0 ----------
# Initial inputs were (nan means no initial input into this SN)
# [ 80.  nan  30. 101. 153. 115. 202.  90.]
# Memory is found
# [ True False False False False  True False False]
# ML decoding gives
# [100. 106. 163.  13. 163.  73. 511. 328.]
# Decoding from the activity vector gives
# [107.15789501 117.17974878 326.91835965  26.08371694 120.69148311
#   69.40565745 414.5741219   63.5755131 ]
#
#
# ---------- Computing capacity, maintained and spurious memories ----------
# 2 maintained memories
# 5 forgotten memories
# 0 spurious memories
#
# All results saved in the folder
# 747

# %%
dic = {'Number_of_trials':5}
MyModel = FlexibleWM(dic)
MyModel.run_a_trial()
# Out:
# Initializing the weights of the network that will be used for all trials
#
# ---------- Initialisation of trial 0 ----------
# Load for this trial is 3
# Running...
# Plot of a raster into the folder ..
# Tuning curve is saved in the folder, next time you can include 'compute_tuning_curve':False to reuse it
#
# ---------- ML decoding at the end of trial 0 ----------
# Initial inputs were (nan means no initial input into this SN)
# [ nan  91. 331.  nan  nan 274.  nan  nan]
# Memory is found
# [False False  True False False  True False False]
# ML decoding gives
# [295. 320. 354. 397. 319. 283. 385. 256.]
# Decoding from the activity vector gives
# [283.99445435 379.52472461 352.35498685 435.51814526 285.52961703
#  279.6186395  499.04141186 272.87778283]
#
#
# ---------- Computing capacity, maintained and spurious memories ----------
# 2 maintained memories
# 1 forgotten memories
# 0 spurious memories
#
# ---------- Initialisation of trial 1 ----------
# Load for this trial is 3
# Running...
# Plot of a raster into the folder ..
# Tuning curve is saved in the folder, next time you can include 'compute_tuning_curve':False to reuse it
#
# ---------- ML decoding at the end of trial 1 ----------
# Initial inputs were (nan means no initial input into this SN)
# [485.  nan  nan  nan  nan 368.  nan 162.]
# Memory is found
# [ True False False False False False False  True]
# ML decoding gives
# [485.  60. 275. 196. 189.   5. 242. 135.]
# Decoding from the activity vector gives
# [481.96312635 155.96133082 438.34669001 200.7548982  169.51484589
#   55.28477831 508.086384   130.34394193]
#
#
# ---------- Computing capacity, maintained and spurious memories ----------
# 2 maintained memories
# 1 forgotten memories
# 0 spurious memories
#
# ---------- Initialisation of trial 2 ----------
# Load for this trial is 3
# Running...
# Plot of a raster into the folder ..
# Tuning curve is saved in the folder, next time you can include 'compute_tuning_curve':False to reuse it
#
# ---------- ML decoding at the end of trial 2 ----------
# Initial inputs were (nan means no initial input into this SN)
# [ nan  nan 357.  nan 174.  nan  nan 479.]
# Memory is found
# [False False  True False False False False  True]
# ML decoding gives
# [473.   5. 354.  94. 230. 392. 397. 498.]
# Decoding from the activity vector gives
# [443.78739561  16.30313458 354.44527632 100.03854929 170.83551212
#  141.16388287 379.35469428 494.59140211]
#
#
# ---------- Computing capacity, maintained and spurious memories ----------
# 2 maintained memories
# 1 forgotten memories
# 0 spurious memories
#
# ---------- Initialisation of trial 3 ----------
# Load for this trial is 4
# Running...
# Plot of a raster into the folder ..
# Tuning curve is saved in the folder, next time you can include 'compute_tuning_curve':False to reuse it
#
# ---------- ML decoding at the end of trial 3 ----------
# Initial inputs were (nan means no initial input into this SN)
# [ nan 273.   8.  nan 435. 154.  nan  nan]
# Memory is found
# [False  True  True False  True False False False]
# ML decoding gives
# [270. 294.   3. 363. 406. 426. 306. 316.]
# Decoding from the activity vector gives
# [331.27892159 295.4191542    7.04559139 286.92769041 409.4735106
#   60.08049345 325.58422207 298.5398411 ]
#
#
# ---------- Computing capacity, maintained and spurious memories ----------
# 3 maintained memories
# 1 forgotten memories
# 0 spurious memories
#
# ---------- Initialisation of trial 4 ----------
# Load for this trial is 1
# Running...
# Plot of a raster into the folder ..
# Tuning curve is saved in the folder, next time you can include 'compute_tuning_curve':False to reuse it
#
# ---------- ML decoding at the end of trial 4 ----------
# Initial inputs were (nan means no initial input into this SN)
# [56. nan nan nan nan nan nan nan]
# Memory is found
# [ True False False False False False False False]
# ML decoding gives
# [ 69. 183.  61. 334. 251.  55.  62. 465.]
# Decoding from the activity vector gives
# [ 63.77939042 131.49622894   0.73600579   3.9019879   49.03880271
#   37.52837744 321.93202086  11.59415237]
#
#
# ---------- Computing capacity, maintained and spurious memories ----------
# 1 maintained memories
# 0 forgotten memories
# 0 spurious memories
#
# All results saved in the folder
